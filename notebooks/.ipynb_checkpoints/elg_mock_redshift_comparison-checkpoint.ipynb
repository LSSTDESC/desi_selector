# %%
import numpy as np
import pandas as pd
from astropy import table
from pathlib import Path
import os
import matplotlib.pyplot as plt
from scipy import interpolate
import treecorr as tc
from astropy.io.misc.hdf5 import read_table_hdf5
from astropy import units as u
from astropy.cosmology import Planck18 as cosmo
from astropy.coordinates import SkyCoord

# %%
AREA_PER_HEALPIX = 57.071968/17

# %%
# loop over the healpix and concat them together into one cat
path_healpix_ids = '/global/homes/y/yoki/roman/desi_like_samples/skysim_5000/data/healpix_ids/id_nums_all.npy'
hpix_ids = np.load(path_healpix_ids)
cat_list = []
rand_list = []


for hpix in hpix_ids:
    path_mock_elgs = f'/global/homes/y/yoki/roman/desi_like_samples/skysim_5000/data/mocks_per_healpix/mock_elg_cat_per_pixel/mock_elg_cat_hpix_{hpix}.parquet'
    mock_elg_cat_loop = pd.read_parquet(path=path_mock_elgs)
    cat_list.append(mock_elg_cat_loop)

mock_elg_cat = pd.concat(cat_list)

for hpix in hpix_ids:
    path_mock_elg_rands = f'/global/homes/y/yoki/roman/desi_like_samples/skysim_5000/data/rands_per_healpix/rands_elg_cat_per_pixel/rand_elg_cat_hpix_{hpix}.parquet'
    mock_elg_rand_loop = pd.read_parquet(path=path_mock_elg_rands)
    rand_list.append(mock_elg_rand_loop)

rand_elg_cat = pd.concat(rand_list)

# %%
len(hpix_ids)
# Out:
# 1568

# %%
mock_elg_cat
# Out:
#       redshift            r       sfr       sfr_tot  stellar_mass  \
# 0     0.028537   125.598410  0.000000  3.996822e+08  1.342526e+09
# 1     0.039718   174.343616  0.015179  3.369026e+08  1.297057e+08
# 2     0.031103   136.807236  0.025546  2.245821e+07  2.221400e+07
# 3     0.043482   190.691982  0.000000  4.496591e+08  6.505978e+08
# 4     0.048938   214.337761  0.000000  3.749500e+08  6.531322e+08
# ...        ...          ...       ...           ...           ...
# 3084  1.646300  4742.107152  0.000000  2.546742e+10  1.474186e+11
# 3085  1.644651  4739.229658  0.000000  2.480027e+10  1.628896e+11
# 3086  1.652714  4753.272075  0.000000  2.730701e+10  2.559567e+11
# 3087  1.656329  4759.549640  0.000000  2.675756e+10  1.428451e+11
# 3088  1.661983  4769.344669  0.000000  2.865462e+10  2.559567e+11
#
#       blackhole_mass        gal_id      mag_u      mag_g      mag_r  \
# 0       0.000000e+00  8.256000e+12  18.588469  17.676609  17.229925
# 1       2.483865e+05  8.256000e+12  21.296926  19.979092  19.321720
# 2       0.000000e+00  8.256000e+12  21.530800  20.568233  20.113045
# 3       9.666244e+05  8.256000e+12  20.557533  19.270355  18.610189
# 4       6.013895e+05  8.256000e+12  20.200113  19.224125  18.739296
# ...              ...           ...        ...        ...        ...
# 3084    6.594511e+08  8.159101e+12  22.685583  22.659302  22.692207
# 3085    9.899019e+08  8.159101e+12  22.606836  22.578228  22.611591
# 3086    3.693237e+09  8.159101e+12  22.235859  22.215435  22.247175
# 3087    4.974351e+08  8.159101e+12  22.712074  22.689981  22.722054
# 3088    1.527472e+09  8.159101e+12  22.214840  22.198246  22.229221
#
#           mag_i      mag_z      mag_y  redshift_hubble         ra        dec  \
# 0     16.920998  16.690367  16.530424         0.029481   0.521529 -21.468722
# 1     18.958403  18.629505  18.450480         0.039350   0.101975 -21.576741
# 2     19.803286  19.640102  19.532309         0.031049   0.208972 -20.042183
# 3     18.212355  17.909027  17.716297         0.043847   0.844725 -20.466282
# 4     18.396175  18.125971  17.965176         0.049360   1.131842 -20.558202
# ...         ...        ...        ...              ...        ...        ...
# 3084  22.642048  22.513321  22.301712         1.647541  88.581942 -20.038092
# 3085  22.555536  22.423342  22.201397         1.642249  89.280873 -19.420490
# 3086  22.212021  22.092262  21.907984         1.662244  88.086254 -19.828837
# 3087  22.682598  22.560249  22.367981         1.657835  88.210109 -19.764257
# 3088  22.204029  22.090332  21.925062         1.673119  89.494083 -19.122336
#
#         ra_true   dec_true
# 0      0.521729 -21.469116
# 1      0.102170 -21.577132
# 2      0.209214 -20.042592
# 3      0.844943 -20.466679
# 4      1.132065 -20.558614
# ...         ...        ...
# 3084  88.585951 -20.043944
# 3085  89.289857 -19.432246
# 3086  88.081765 -19.834303
# 3087  88.209012 -19.771573
# 3088  89.495096 -19.133076
#
# [4843552 rows x 18 columns]

# %%
rand_elg_cat
# Out:
#                ra        dec            r
# 0        0.761075 -21.303715  3162.026250
# 1        0.041681 -21.309744  2687.191020
# 2      359.460381 -21.422891  3653.577356
# 3        0.310518 -20.574835  3459.629110
# 4        0.885330 -20.765657  3179.331797
# ...           ...        ...          ...
# 30885   89.063628 -20.001693  3111.739835
# 30886   89.344389 -19.443904  2555.847203
# 30887   88.179524 -19.049841  2969.789904
# 30888   88.345286 -19.941488  3164.796019
# 30889   88.153881 -19.385988  3460.030247
#
# [47099020 rows x 3 columns]

# %%
# load in the desi ELG distributions 
path_desi_data = Path('../data/desi_sv_data/desi_elg_ts_zenodo/main-800coaddefftime1200-nz-zenodo.ecsv')
desi_data = table.Table.read(path_desi_data, format='ascii.ecsv')
desi_data.colnames
zmin = desi_data['ZMIN']
zmax = desi_data['ZMAX']

lop_north = desi_data['ELG_LOP_NORTH']
lop_south_decal = desi_data['ELG_LOP_SOUTH_DECALS']
lop_south_des = desi_data['ELG_LOP_SOUTH_DES']
vlo_north = desi_data['ELG_VLO_NORTH']
vlo_south_decal = desi_data['ELG_VLO_SOUTH_DECALS']
vlo_south_des = desi_data['ELG_VLO_SOUTH_DES']

lop_desi = desi_data['ELG_LOP_DESI']
vlo_desi = desi_data['ELG_VLO_DESI']
weightedavg = (lop_north * 4400 + lop_south_decal * 8500 + lop_south_des * 1100 )/(14000)


#values, edges = np.histogram(spectro_z[ccuts], bins=np.linspace(0, 2, 41))

# %%
plt.scatter(mock_elg_cat['ra'], mock_elg_cat['dec'], label='mock elg')
plt.scatter(rand_elg_cat['ra'], rand_elg_cat['dec'], label='randoms', s=1, color='red')
# plt.xlim(53, 55)
# plt.ylim(-41, -36)
plt.ylabel('DEC', fontsize=19 )
plt.xlabel('RA', fontsize=19)
plt.legend(loc='lower right')

# %%
ra_length = np.max(mock_elg_cat['ra']) - np.min(mock_elg_cat['ra'])
dec_width = np.max(mock_elg_cat['dec']) - np.min(mock_elg_cat['dec'])
area_full = ra_length * dec_width
print(f'The total area of all healpix for SkySim5000 is {area_full}')
# Out:
# The total area of all healpix for SkySim5000 is 4500.333974674151

# %%
values_sim, edges = np.histogram(mock_elg_cat['redshift'], bins=np.linspace(0, 2, 41))


fig, ax = plt.subplots()
ax.stairs(weightedavg, edges, linewidth=2, color ='grey', label= 'DESI LOP ELGs')
ax.stairs(values_sim/(len(hpix_ids)*AREA_PER_HEALPIX), edges, linewidth=2, color='blue', label='DESI Mock ELGs')
# ax.axvline(x=1.10,ls='--', color='black')
# ax.axvline(x=1.60,ls='--', color='black')
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
ax.set_xlabel('redshift', fontsize=30)
ax.set_ylabel('Observed N [$deg^{-2}]$', fontsize=30)
ax.legend(loc='upper left', fontsize=12)
